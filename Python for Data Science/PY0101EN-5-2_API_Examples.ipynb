# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Simple APIs
#
# ## Random User and Fruitvice API Examples
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#
# *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more\
#     productive.
# *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#     independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#
# *   **Secirity**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data\
#     breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
#
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# *   get_cell()
# *   get_city()
# *   get_dob()
# *   get_email()
# *   get_first_name()
# *   get_full_name()
# *   get_gender()
# *   get_id()
# *   get_id_number()
# *   get_id_type()
# *   get_info()
# *   get_last_name()
# *   get_login_md5()
# *   get_login_salt()
# *   get_login_sha1()
# *   get_login_sha256()
# *   get_nat()
# *   get_password()
# *   get_phone()
# *   get_picture()
# *   get_postcode()
# *   get_registered()
# *   get_state()
# *   get_street()
# *   get_username()
# *   get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7fa5b33df5e0>,
#  <randomuser.RandomUser at 0x7fa5b4b53610>,
#  <randomuser.RandomUser at 0x7fa5b422ed60>,
#  <randomuser.RandomUser at 0x7fa5b422ee50>,
#  <randomuser.RandomUser at 0x7fa5b422ec10>,
#  <randomuser.RandomUser at 0x7fa5b422ea60>,
#  <randomuser.RandomUser at 0x7fa5b422e8b0>,
#  <randomuser.RandomUser at 0x7fa5b422e6d0>,
#  <randomuser.RandomUser at 0x7fa5b422eee0>,
#  <randomuser.RandomUser at 0x7fa5b422e730>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Andresa Peixoto   andresa.peixoto@example.com
# Josefina Vega   josefina.vega@example.com
# Adam Martin   adam.martin@example.com
# Nalan Babacan   nalan.babacan@example.com
# Rainer Louis   rainer.louis@example.com
# Harry Williams   harry.williams@example.com
# Ida Cooper   ida.cooper@example.com
# Wladimir Schreier   wladimir.schreier@example.com
# Lícidas Novaes   licidas.novaes@example.com
# Dean Martinez   dean.martinez@example.com

# %% [markdown]
# ## Exercise 1
#
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here

users_with_photos = r.generate_users(5)
for user in users_with_photos:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/9.jpg
# https://randomuser.me/api/portraits/men/98.jpg
# https://randomuser.me/api/portraits/men/4.jpg
# https://randomuser.me/api/portraits/women/49.jpg
# https://randomuser.me/api/portraits/women/23.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                      Name  Gender             City           State  \
# 0        Gabriella Engert  female  Hatzfeld (Eder)          Bayern
# 1         Jovelino Santos    male          Caruaru  Rio de Janeiro
# 2              Ella Ahola  female          Pälkäne         Lapland
# 3              دینا حسینی  female         بندرعباس           کرمان
# 4  Benjamin Jean-Baptiste    male        Inverness   New Brunswick
# 5     Magnus Christiansen    male         Hirtsals     Nordjylland
# 6               یسنا گلشن  female           اردبیل          اصفهان
# 7           Ceylan Eliçin  female            Iğdır      Diyarbakır
# 8              آریا پارسا    male             ساوه              قم
# 9              Riley Shaw  female         Brisbane      Queensland
#
#                                 Email                       DOB  \
# 0        gabriella.engert@example.com  1967-12-27T02:42:53.608Z
# 1         jovelino.santos@example.com  1996-02-16T00:46:08.088Z
# 2              ella.ahola@example.com  1953-06-13T12:16:33.773Z
# 3               dyn.hsyny@example.com  1994-08-21T02:01:00.483Z
# 4  benjamin.jean-baptiste@example.com  1982-01-16T17:19:34.992Z
# 5     magnus.christiansen@example.com  1969-11-17T17:28:57.433Z
# 6               ysn.glshn@example.com  1981-01-26T17:37:16.490Z
# 7           ceylan.elicin@example.com  1944-09-10T11:30:56.118Z
# 8                 ary.prs@example.com  1965-07-13T12:10:04.956Z
# 9              riley.shaw@example.com  1965-07-25T11:48:07.079Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/15.jpg
# 1    https://randomuser.me/api/portraits/men/11.jpg
# 2  https://randomuser.me/api/portraits/women/68.jpg
# 3   https://randomuser.me/api/portraits/women/2.jpg
# 4     https://randomuser.me/api/portraits/men/7.jpg
# 5    https://randomuser.me/api/portraits/men/98.jpg
# 6  https://randomuser.me/api/portraits/women/50.jpg
# 7  https://randomuser.me/api/portraits/women/83.jpg
# 8    https://randomuser.me/api/portraits/men/65.jpg
# 9  https://randomuser.me/api/portraits/women/32.jpg

# %%
df1 = pd.DataFrame(get_users())

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae              None
# 7   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 8          Durio        Durian  60        Malvaceae          Malvales
# 9     Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 10         Ficus           Fig  68         Moraceae           Rosales
# 11         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 12         Vitis         Grape  81         Vitaceae           Vitales
# 13         Vitis        Grapes  47         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28         Pyrus          Pear   4         Rosaceae           Rosales
# 29     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 30        Ananas     Pineapple  10     Bromeliaceae            Poales
# 31     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 32        Prunus          Plum  71         Rosaceae           Rosales
# 33        Punica   Pomegranate  79       Lythraceae          Myrtales
# 34         Rubus     Raspberry  23         Rosaceae           Rosales
# 35      Fragaria    Strawberry   3         Rosaceae           Rosales
# 36        Citrus     Tangerine  77         Rutaceae        Sapindales
# 37       Solanum        Tomato   5       Solanaceae         Solanales
# 38     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 8.53, 'protein': 2, 'fat': 1...
# 3   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 4   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 5   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 6   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 7   {'carbohydrates': 9, 'protein': 9, 'fat': 1.5,...
# 8   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 9   {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....
# 10  {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 11  {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 12  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 13  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 14  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 15  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 16  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 17  {'carbohydrates': 14.6, 'protein': 1.14, 'fat'...
# 18  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 19  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 20  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 21  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 22  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 23  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 24  {'carbohydrates': 9.8, 'protein': 1.44, 'fat':...
# 25  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 26  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 27  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 28  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 29  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 30  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 31  {'carbohydrates': 7, 'protein': 1, 'fat': 0.4,...
# 32  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 33  {'carbohydrates': 18.7, 'protein': 1.7, 'fat':...
# 34  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 35  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 36  {'carbohydrates': 8.3, 'protein': 0, 'fat': 0....
# 37  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 38  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae              None
# 7   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 8          Durio        Durian  60        Malvaceae          Malvales
# 9     Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 10         Ficus           Fig  68         Moraceae           Rosales
# 11         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 12         Vitis         Grape  81         Vitaceae           Vitales
# 13         Vitis        Grapes  47         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28         Pyrus          Pear   4         Rosaceae           Rosales
# 29     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 30        Ananas     Pineapple  10     Bromeliaceae            Poales
# 31     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 32        Prunus          Plum  71         Rosaceae           Rosales
# 33        Punica   Pomegranate  79       Lythraceae          Myrtales
# 34         Rubus     Raspberry  23         Rosaceae           Rosales
# 35      Fragaria    Strawberry   3         Rosaceae           Rosales
# 36        Citrus     Tangerine  77         Rutaceae        Sapindales
# 37       Solanum        Tomato   5       Solanaceae         Solanales
# 38     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                       8.53                2.00           14.66
# 3                      22.00                1.00            0.20
# 4                       9.00                1.30            0.40
# 5                       5.50                0.00            0.40
# 6                      12.00                1.00            0.30
# 7                       9.00                9.00            1.50
# 8                      27.10                1.50            5.30
# 9                       8.00                0.60            0.40
# 10                     19.00                0.80            0.30
# 11                     10.00                0.90            0.60
# 12                     18.10                0.72            0.16
# 13                     18.10                0.72            0.16
# 14                      3.10                0.40            0.10
# 15                     14.00                2.60            1.00
# 16                     15.00                1.10            0.50
# 17                     14.60                1.14            0.50
# 18                      9.00                1.10            0.30
# 19                      8.40                0.30            0.10
# 20                     11.30                0.75            0.34
# 21                     17.00                0.80            0.44
# 22                     15.00                0.82            0.38
# 23                      8.00                0.00            0.00
# 24                      9.80                1.44            0.39
# 25                      8.30                1.00            0.20
# 26                     11.00                0.00            0.40
# 27                     22.40                2.20            0.70
# 28                     15.00                0.40            0.10
# 29                     18.00                0.00            0.00
# 30                     13.12                0.54            0.12
# 31                      7.00                1.00            0.40
# 32                     11.40                0.70            0.28
# 33                     18.70                1.70            1.20
# 34                     12.00                1.20            0.70
# 35                      5.50                0.80            0.40
# 36                      8.30                0.00            0.40
# 37                      3.90                0.90            0.20
# 38                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                   160              0.66
# 3                    96             17.20
# 4                    40              4.50
# 5                    29              5.40
# 6                    50              8.00
# 7                    60              8.00
# 8                   147              6.75
# 9                    44              3.00
# 10                   74             16.00
# 11                   44              0.00
# 12                   69             16.00
# 13                   69             15.48
# 14                   21              6.40
# 15                   68              9.00
# 16                   61              9.00
# 17                   61              8.90
# 18                   29              2.50
# 19                   25              1.70
# 20                   50              5.74
# 21                   66             15.00
# 22                   60             13.70
# 23                   34              8.00
# 24                   43              8.10
# 25                   43              8.20
# 26                   43              1.00
# 27                   97             11.20
# 28                   57             10.00
# 29                   81             18.00
# 30                   50              9.85
# 31                   36              3.00
# 32                   46              9.92
# 33                   83             13.70
# 34                   53              4.40
# 35                   29              5.40
# 36                   45              9.10
# 37                   74              2.60
# 38                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
#
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
df2[df2['name'] == 'Banana']['nutritions.calories']
# Out:
# 3    96
# Name: nutritions.calories, dtype: int64

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
#
# 1.  Using `requests.get("url")` function, load your data.

# %%
# Write your code here
dogs_data = requests.get('https://dog.ceo/api/breeds/list')

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2.  Retrieve results using `json.loads()` function.

# %%
dogs_data
# Out:
# <Response [200]>

# %%
# Write your code here
dogs_result = json.loads(dogs_data.text)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3.  Convert json data into *pandas* data frame.

# %%
# Write your code here
dogs_dataframe = pd.DataFrame(dogs_result)

# %%
dogs_dataframe
# Out:
#                  message   status
# affenpinscher         []  success
# african               []  success
# airedale              []  success
# akita                 []  success
# appenzeller           []  success
# ...                  ...      ...
# vizsla                []  success
# waterdog       [spanish]  success
# weimaraner            []  success
# whippet               []  success
# wolfhound        [irish]  success
#
# [98 rows x 2 columns]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
#
# [Svitlana Kramar](https://www.linkedin.com/in/svitlana-kramar?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01)
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
# Copyright © 2020 IBM Corporation. All rights reserved.
